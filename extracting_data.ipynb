# %%
pip install rasterio
# Out:
# Collecting rasterioNote: you may need to restart the kernel to use updated packages.
#   Downloading rasterio-1.3.10-cp38-cp38-win_amd64.whl (24.4 MB)
# Requirement already satisfied: pandas in c:\users\aizax\anaconda3\lib\site-packages (1.2.4)
#
# Requirement already satisfied: numpy in c:\users\aizax\anaconda3\lib\site-packages (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\aizax\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\aizax\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\aizax\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: attrs in c:\users\aizax\anaconda3\lib\site-packages (from rasterio) (20.3.0)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: importlib-metadata in c:\users\aizax\anaconda3\lib\site-packages (from rasterio) (3.10.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click>=4.0 in c:\users\aizax\anaconda3\lib\site-packages (from rasterio) (7.1.2)
# Requirement already satisfied: certifi in c:\users\aizax\anaconda3\lib\site-packages (from rasterio) (2020.12.5)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in c:\users\aizax\anaconda3\lib\site-packages (from rasterio) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\aizax\anaconda3\lib\site-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\aizax\anaconda3\lib\site-packages (from importlib-metadata->rasterio) (3.4.1)
# Installing collected packages: snuggs, cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.3.10 snuggs-1.4.7

# %%
pip install gdal
# Out:
# Collecting gdal
#   Using cached gdal-3.9.1.tar.gz (840 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Building wheels for collected packages: gdal
#   Building wheel for gdal (PEP 517): started
#   Building wheel for gdal (PEP 517): finished with status 'error'
# Failed to build gdal
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\aizax\anaconda3\python.exe' 'C:\Users\aizax\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\aizax\AppData\Local\Temp\tmpuh2ljfx5'
#        cwd: C:\Users\aizax\AppData\Local\Temp\pip-install-iwpkjyck\gdal_72748472267c4f65afe3679be6681e66
#   Complete output (126 lines):
#   Using numpy 1.17.3
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-38
#   creating build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\gdal.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\gdalconst.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\gdalnumeric.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\gdal_array.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\gnm.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\ogr.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\osr.py -> build\lib.win-amd64-cpython-38\osgeo
#   copying osgeo\__init__.py -> build\lib.win-amd64-cpython-38\osgeo
#   creating build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal2tiles.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal2xyz.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdalattachpct.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdalcompare.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdalmove.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_calc.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_edit.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_fillnodata.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_merge.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_pansharpen.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_polygonize.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_proximity.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_retile.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_sieve.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\ogrmerge.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\ogr_layer_algebra.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\pct2rgb.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\rgb2pct.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   copying gdal-utils\osgeo_utils\__init__.py -> build\lib.win-amd64-cpython-38\osgeo_utils
#   creating build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\array_util.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\base.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\batch_creator.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\color_palette.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\color_table.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\extent_util.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\gdal_argparse.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\numpy_util.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\osr_util.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\progress.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\raster_creation.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\rectangle.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\util.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\__init__.py -> build\lib.win-amd64-cpython-38\osgeo_utils\auxiliary
#   creating build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\assemblepoly.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\build_jp2_from_xml.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\classify.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\crs2crs2grid.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\densify.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\dump_jp2.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\epsg_tr.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\esri2wkt.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\fft.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\fix_gpkg.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gcps2ogr.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gcps2vec.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gcps2wld.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal2grd.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalbuildvrtofvrt.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalchksum.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalcopyproj.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalfilter.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalident.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalimport.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalinfo.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdallocationinfo.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_auth.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_cp.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_create_pdf.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_ls.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_lut.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_mkdir.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_remove_towgs84.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_rm.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_rmdir.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_vrtmerge.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\get_soundg.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\histrep.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\hsv_merge.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\jpeg_in_tiff_extract.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\load2odbc.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\loslas2ntv2.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\magphase.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\make_fuzzer_friendly_archive.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\mkgraticule.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogr2vrt.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogrinfo.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogrupdate.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogr_build_junction_table.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogr_dispatch.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\rel.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\tigerpoly.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\tile_extent_from_raster.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\tolatlong.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_cloud_optimized_geotiff.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_geoparquet.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_gpkg.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_jp2.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\val_repl.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\vec_tr.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\vec_tr_spat.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\wcs_virtds_params.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\__init__.py -> build\lib.win-amd64-cpython-38\osgeo_utils\samples
#   running egg_info
#   writing gdal-utils\GDAL.egg-info\PKG-INFO
#   writing dependency_links to gdal-utils\GDAL.egg-info\dependency_links.txt
#   writing entry points to gdal-utils\GDAL.egg-info\entry_points.txt
#   writing requirements to gdal-utils\GDAL.egg-info\requires.txt
#   writing top-level names to gdal-utils\GDAL.egg-info\top_level.txt
#   reading manifest file 'gdal-utils\GDAL.egg-info\SOURCES.txt'
#   writing manifest file 'gdal-utils\GDAL.egg-info\SOURCES.txt'
#   running build_ext
#   building 'osgeo._gdal' extension
#   building 'osgeo._ogr' extension
#   building 'osgeo._osr' extension
#   building 'osgeo._gdal_array' extension
#   building 'osgeo._gnm' extension
#   building 'osgeo._gdalconst' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for gdal
# ERROR: Could not build wheels for gdal which use PEP 517 and cannot be installed directly

# %%
conda install gdal
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda --version
# Out:
# conda 4.10.3
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.version)
# Out:
# 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]

# %%
import rasterio
import pandas as pd
import numpy as np
import zipfile
from io import BytesIO

def tiff_to_csv(tiff_path):
    # Open the TIFF file
    with rasterio.open(tiff_path) as src:
        # Read the data
        data = src.read(1)  # Assuming single band, use src.read() for all bands
        
        # Get coordinates
        height, width = data.shape
        cols, rows = np.meshgrid(np.arange(width), np.arange(height))
        xs, ys = rasterio.transform.xy(src.transform, rows, cols)
        
        # Convert xs and ys to NumPy arrays if they're not already
        xs = np.array(xs)
        ys = np.array(ys)
        
        # Create a dataframe
        df = pd.DataFrame({
            'x': xs.flatten(),
            'y': ys.flatten(),
            'value': data.flatten()
        })
    return df

def tiff_to_csv_from_zip(zip_path, tiff_name):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        with zip_ref.open(tiff_name) as tiff_file:
            with rasterio.open(BytesIO(tiff_file.read())) as src:
                # Read the data
                data = src.read(1)  # Assuming single band, use src.read() for all bands
                
                # Get coordinates
                height, width = data.shape
                cols, rows = np.meshgrid(np.arange(width), np.arange(height))
                xs, ys = rasterio.transform.xy(src.transform, rows, cols)
                
                # Convert xs and ys to NumPy arrays if they're not already
                xs = np.array(xs)
                ys = np.array(ys)
                
                # Create a dataframe
                df = pd.DataFrame({
                    'x': xs.flatten(),
                    'y': ys.flatten(),
                    'value': data.flatten()
                })
    return df

# Example usage
# tiff_to_csv_from_zip('data.zip', 'input.tif', 'output.csv')

# %%
csv_path='home\Documents\classes\biomassProject\ClusterAnalysis'
tiff_path='swbiomass_data1\gedi\gedi_2019-2023.tif'
zip_path='D:\Biomass\swbiomass_data1.zip'

data=tiff_to_csv_from_zip(zip_path, tiff_path)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-8e0779d2f8eb> in <module>
#       3 zip_path='D:\Biomass\swbiomass_data1.zip'
#       4
# ----> 5 data=tiff_to_csv_from_zip(zip_path, tiff_path)
#       6 data
#
# <ipython-input-55-270daf188c82> in tiff_to_csv_from_zip(zip_path, tiff_name)
#      30 def tiff_to_csv_from_zip(zip_path, tiff_name):
#      31     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
# ---> 32         with zip_ref.open(tiff_name) as tiff_file:
#      33             with rasterio.open(BytesIO(tiff_file.read())) as src:
#      34                 # Read the data
#
# ~\anaconda3\lib\zipfile.py in open(self, name, mode, pwd, force_zip64)
#    1512         else:
#    1513             # Get info object for name
# -> 1514             zinfo = self.getinfo(name)
#    1515
#    1516         if mode == 'w':
#
# ~\anaconda3\lib\zipfile.py in getinfo(self, name)
#    1439         info = self.NameToInfo.get(name)
#    1440         if info is None:
# -> 1441             raise KeyError(
#    1442                 'There is no item named %r in the archive' % name)
#    1443
#
# KeyError: "There is no item named 'swbiomass_data1\\\\gedi\\\\gedi_2019-2023.tif' in the archive"

# %%
import os
import zipfile

path_to_folder = r"D:\Biomass\swbiomass_data1.zip"

if os.path.exists(path_to_folder):
    print("Files in the zip archive:")
    with zipfile.ZipFile(path_to_folder, 'r') as zip_ref:
        for file in zip_ref.namelist():
            print(file)
else:
    print("The specified path does not exist.")
# Out:
# Files in the zip archive:
# swbiomass_data1/chopping/
# swbiomass_data1/chopping/chopping_2000-2021.tif
# swbiomass_data1/chopping/chopping_2000-2021.tif.aux.json
# swbiomass_data1/esa_cci/
# swbiomass_data1/esa_cci/esa.cci_N40W110_2010.2017-2020.tif
# swbiomass_data1/esa_cci/esa.cci_N40W110_2010.2017-2020.tif.aux.json
# swbiomass_data1/esa_cci/esa.cci_N40W120_2010.2017-2020.tif
# swbiomass_data1/esa_cci/esa.cci_N40W120_2010.2017-2020.tif.aux.json
# swbiomass_data1/esa_cci/esa.cci_N40W130_2010.2017-2020.tif
# swbiomass_data1/esa_cci/esa.cci_N40W130_2010.2017-2020.tif.aux.json
# swbiomass_data1/esa_cci/esa.cci_N50W120_2010.2017-2020.tif
# swbiomass_data1/esa_cci/esa.cci_N50W120_2010.2017-2020.tif.aux.json
# swbiomass_data1/esa_cci/esa.cci_N50W130_2010.2017-2020.tif
# swbiomass_data1/esa_cci/esa.cci_N50W130_2010.2017-2020.tif.aux.json
# swbiomass_data1/gedi/
# swbiomass_data1/gedi/gedi_2019-2023.tif
# swbiomass_data1/gedi/gedi_2019-2023.tif.aux.json
# swbiomass_data1/liu/
# swbiomass_data1/liu/liu_1993-2012.tif
# swbiomass_data1/liu/liu_1993-2012.tif.aux.json
# swbiomass_data1/lt_gnn/
# swbiomass_data1/lt_gnn/lt.gnn_h01v05_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h01v05_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h01v06_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h01v06_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h01v07_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h01v07_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h01v08_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h01v08_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h01v09_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h01v09_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h01v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h01v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v05_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v05_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v06_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v06_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v07_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v07_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v08_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v08_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v09_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v09_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h02v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h02v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v05_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v05_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v06_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v06_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v07_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v07_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v08_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v08_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v09_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v09_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h03v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h03v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v07_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v07_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v08_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v08_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v09_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v09_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h04v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h04v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h05v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h05v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h05v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h05v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h05v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h05v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h05v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h05v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h05v14_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h05v14_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h06v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h06v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h06v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h06v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h06v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h06v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h06v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h06v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h06v14_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h06v14_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h07v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h07v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h07v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h07v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h07v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h07v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h07v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h07v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h07v14_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h07v14_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h07v15_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h07v15_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h08v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h08v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h08v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h08v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h08v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h08v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h08v14_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h08v14_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h08v15_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h08v15_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h09v10_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h09v10_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h09v11_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h09v11_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h09v12_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h09v12_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h09v13_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h09v13_1990-2017.tif.aux.json
# swbiomass_data1/lt_gnn/lt.gnn_h09v14_1990-2017.tif
# swbiomass_data1/lt_gnn/lt.gnn_h09v14_1990-2017.tif.aux.json
# swbiomass_data1/menlove/
# swbiomass_data1/menlove/menlove_2009-2019.tif
# swbiomass_data1/menlove/menlove_2009-2019.tif.aux.json
# swbiomass_data1/xu/
# swbiomass_data1/xu/xu_2000-2029.tif
# swbiomass_data1/xu/xu_2000-2029.tif.aux.json

# %%
import os
print("Current working directory:", os.getcwd())

# On Windows, list available drives
if os.name == 'nt':
    import win32api
    drives = win32api.GetLogicalDriveStrings()
    print("Available drives:", drives.split('\000')[:-1])

# On Unix-like systems (macOS, Linux), list contents of /Volumes or /media
if os.name == 'posix':
    print("Contents of /Volumes:", os.listdir('/Volumes'))
    # or
    print("Contents of /media:", os.listdir('/media'))
# Out:
# Current working directory: C:\Users\aizax\Documents\classes\biomassProject\ClusterAnalysis
# Available drives: ['C:\\', 'D:\\']

# %%
tiff_path=r'D:\Biomass\swbiomass_data1\swbiomass_data1\esa_cci\esa.cci_N40W110_2010.2017-2020.tif'

data=tiff_to_csv(tiff_path)
data
# Out:
#                     x          y  value
# 0         -109.999556  39.999556      0
# 1         -109.998667  39.999556      0
# 2         -109.997778  39.999556      0
# 3         -109.996889  39.999556      0
# 4         -109.996000  39.999556      0
# ...               ...        ...    ...
# 126562495 -100.004000  30.000444     65
# 126562496 -100.003111  30.000444     50
# 126562497 -100.002222  30.000444     50
# 126562498 -100.001333  30.000444     31
# 126562499 -100.000444  30.000444      0
#
# [126562500 rows x 3 columns]

# %%
#Save to CSV
csv_path='home\Documents\classes\biomassProject\ClusterAnalysis\esa.csv'

df.to_csv(csv_path, index=False)

# %%
#FROM YANG

import numpy as np
import pandas as pd
from osgeo import gdal

rasterfn = r"D:\AGB_project\aiza\esa.cci_N40W110_2010.2017-2020.tif"
outf = r"D:\AGB_project\aiza\average.csv"
raster = gdal.Open(rasterfn) # load tiff file

RasterCount = raster.RasterCount # get band number

year_list = [] # init year list
value_list = [] # init value list
for i in range(1,RasterCount+1): # read each band
    band = raster.GetRasterBand(i) # get band
    band_name = band.GetDescription() # get band name

    array = band.ReadAsArray() # read as array
    array = np.array(array,dtype=float) # convert array to float
    array[array<=0] = np.nan # for AGB, set 0 to nan
    array_mean = np.nanmean(array) # calculate mean, ignore nan

    year_list.append(band_name) # append year
    value_list.append(array_mean) # append value
df = pd.DataFrame({'year':year_list,'value':value_list}) # create dataframe
df.to_csv(outf,index=False) # save dataframe to csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f8c73d801d30> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from osgeo import gdal
#       4
#       5 rasterfn = r"D:\AGB_project\aiza\esa.cci_N40W110_2010.2017-2020.tif"
#
# ModuleNotFoundError: No module named 'osgeo'
