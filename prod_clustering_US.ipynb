# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering, KMeans, AffinityPropagation
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

from utils import *

# %%
# Load the dataset
biomass_data = pd.read_csv('site_data.csv')

# %%
#Clustering products

# Transpose the DataFrame to have products as rows and locations as columns
data_transposed = biomass_data.set_index(['dataset', 'site_name', 'site_id', 'X', 'Y']).T

# Remove non-numeric rows
data_transposed_numeric = data_transposed.select_dtypes(include=[np.number])

# Replace 'NA' with NaN
data_transposed_numeric = data_transposed_numeric.replace('NA', np.nan)

# Drop rows with all NaN values
data_transposed_numeric = data_transposed_numeric.dropna(axis=1, how='all')

# Impute missing values with column mean
imputer = SimpleImputer(strategy='mean')
# Impute missing values with ROW mean (must use transposed df and axis=1 for rows)
data_imputed = data_transposed_numeric.T.fillna(data_transposed_numeric.mean(axis=1)).T

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_imputed)

# %% [markdown]
# ## hierarchical

# %%
#hierarchical clustering
cluster_h = AgglomerativeClustering(n_clusters=3, linkage='ward')
clusters_h = cluster_h.fit_predict(data_scaled)

# %%
# Add cluster labels to the transposed DataFrame, for 1)
data_imputed.loc[:,'cluster'] = clusters_h

# Transpose the data back to the original format
biomass_data_clustered_h = data_imputed.reset_index()

# %%
biomass_data_clustered_h
# Out:
# dataset               index               NEON  \
# site_name                       Harvard Forest
# site_id                                   HARV
# X                           -72.17265999999995
# Y                            42.53690000000006
# 0                   ESA CCI          21.046901
# 1           Chopping et al.          18.783055
# 2                  GEDI L4B         164.080719
# 3                Liu et al.          37.921211
# 4                    LT-GNN          31.403246
# 5          Menlove & Healey         114.922806
# 6                 Xu et al.          69.325028
#
# dataset                                               \
# site_name Smithsonian Conservation Biology Institute
# site_id                                         SCBI
# X                                 -78.13949999999994
# Y                                  38.89292000000006
# 0                                          21.046901
# 1                                          18.783055
# 2                                         334.279755
# 3                                         115.212837
# 4                                          31.403246
# 5                                         106.782768
# 6                                          69.325028
#
# dataset                                                         \
# site_name Ordway-Swisher Biological Station             UNDERC
# site_id                                OSBS               UNDE
# X                        -81.99342999999999 -89.53724999999997
# Y                         29.68927000000008  46.23388000000006
# 0                                 21.046901          21.046901
# 1                                 18.783055          18.783055
# 2                                 63.379155         155.069643
# 3                                 69.890287         139.331772
# 4                                 31.403246          31.403246
# 5                                 42.734001          91.699257
# 6                                 69.325028          69.325028
#
# dataset                                                        \
# site_name Konza Prairie Biological Station          Oak Ridge
# site_id                               KONZ               ORNL
# X                                -96.56309 -84.28259999999995
# Y                        39.10077000000007  35.96412000000004
# 0                                21.046901          21.046901
# 1                                18.783055          18.783055
# 2                                 7.477551         162.482702
# 3                                10.838812          91.845345
# 4                                31.403246          31.403246
# 5                                10.135107         115.705890
# 6                                69.325028          69.325028
#
# dataset                                                 \
# site_name Talladega National Forest          Woodworth
# site_id                        TALL               WOOD
# X                -87.39326999999997 -99.24135599999994
# Y                 32.95046000000008  47.12822800000004
# 0                         21.046901          21.046901
# 1                         18.783055          18.783055
# 2                        228.355491           4.161302
# 3                         85.784576           9.719982
# 4                         31.403246          31.403246
# 5                        125.903267           0.000000
# 6                         69.325028          69.325028
#
# dataset                                      ...  \
# site_name Central Plains Experimental Range  ...
# site_id                                CPER  ...
# X                            -104.745602469  ...
# Y                         40.81553413400008  ...
# 0                                 21.046901  ...
# 1                                  0.000000  ...
# 2                                  1.268689  ...
# 3                                  9.621728  ...
# 4                                 31.403246  ...
# 5                                  0.000000  ...
# 6                                  0.000000  ...
#
# dataset                               Ameriflux                              \
# site_name NEON Talladega National Forest (TALL) NEON Lower Teakettle (TEAK)
# site_id                                  US-xTA                      US-xTE
# X                                      -87.3933                    -119.006
# Y                                       32.9505                     37.0058
# 0                                     21.046901                  141.225123
# 1                                     18.783055                  226.943207
# 2                                    228.293116                  113.171759
# 3                                     85.784576                   40.415094
# 4                                     31.403246                  248.404526
# 5                                    125.903267                  176.307236
# 6                                     69.325028                  176.820676
#
# dataset                          \
# site_name NEON Treehaven (TREE)
# site_id                  US-xTR
# X                      -89.5857
# Y                       45.4937
# 0                     21.046901
# 1                     18.783055
# 2                    111.140861
# 3                     51.776399
# 4                     31.403246
# 5                     44.224957
# 6                     69.325028
#
# dataset                                                       \
# site_name NEON The University of Kansas Field Station (UKFS)
# site_id                                               US-xUK
# X                                                   -95.1921
# Y                                                    39.0404
# 0                                                  21.046901
# 1                                                  18.783055
# 2                                                  88.286984
# 3                                                  27.528269
# 4                                                  31.403246
# 5                                                  29.088547
# 6                                                  69.325028
#
# dataset                                                                       \
# site_name NEON University of Notre Dame Environmental Research Center (UNDE)
# site_id                                                               US-xUN
# X                                                                   -89.5373
# Y                                                                    46.2339
# 0                                                  21.046901
# 1                                                  18.783055
# 2                                                 155.035292
# 3                                                 139.331772
# 4                                                  31.403246
# 5                                                  91.699257
# 6                                                  69.325028
#
# dataset                                                                     \
# site_name NEON Woodworth (WOOD) NEON Wind River Experimental Forest (WREF)
# site_id                  US-xWD                                     US-xWR
# X                      -99.2414                                  -121.9519
# Y                       47.1282                                    45.8205
# 0                     21.046901                                 244.415145
# 1                     18.783055                                  18.783055
# 2                      4.150213                                 357.726868
# 3                      9.719900                                 194.783264
# 4                     31.403246                                  31.403246
# 5                      0.000000                                 320.595123
# 6                     69.325028                                 819.682068
#
# dataset                                                                        \
# site_name NEON Yellowstone Northern Range (Frog Rock) (YELL) Yellow Cab urban
# site_id                                               US-xYE           US-Ylw
# X                                                  -110.5391         -95.3536
# Y                                                    44.9535          29.7894
# 0                                                   7.986143        21.046901
# 1                                                  18.783055        18.783055
# 2                                                  37.207724         7.105864
# 3                                                  59.854660        20.670036
# 4                                                  31.403246        31.403246
# 5                                                  36.563770         8.727328
# 6                                                  79.867683        69.325028
#
# dataset   cluster
# site_name
# site_id
# X
# Y
# 0               2
# 1               2
# 2               0
# 3               0
# 4               2
# 5               0
# 6               1
#
# [7 rows x 499 columns]

# %%
clusters_h
if -1 in clusters_h:
    print("noise found during clustering, contained in cluster -1")

# %%
# Save the clustering results to a CSV file
biomass_data_clustered_h.to_csv('By_Prod\product_clusters_h_US.csv', index=False)

# %%
# List of products
products = ['ESA CCI', 'Chopping et al.', 'GEDI L4B', 'Liu et al.', 'LT-GNN', 'Menlove & Healey', 'Xu et al.']

corr_matrix=plot_heat_by_clus(biomass_data_clustered_h,products)
# Out:
# biomass_data_clustered has more columns than rows, clustering occured on products
# Cluster 2 contains multiple products, plotting heatmap...
# Cluster 0 contains multiple products, plotting heatmap...

# %%
# METRICS

# Extract predicted cluster labels
predicted_labels = biomass_data_clustered['cluster']

print_indices(data_scaled, predicted_labels)
# Out:
# Silhouette Coefficient: 0.22890319328004938
# Calinski-Harabasz Index: 4.119086607194342
# Davies-Bouldin Index: 0.8237222880542179

# %% [markdown]
# ## Kmeans

# %%
# kmeans clustering
cluster = KMeans(n_clusters=5)
clusters = cluster.fit_predict(data_scaled)

# Add cluster labels to the transposed DataFrame, for 1)
data_imputed.loc[:,'cluster'] = clusters

# Transpose the data back to the original format
biomass_data_clustered = data_imputed.reset_index()
biomass_data_clustered
# Out:
# dataset               index               NEON  \
# site_name                       Harvard Forest
# site_id                                   HARV
# X                           -72.17265999999995
# Y                            42.53690000000006
# 0                   ESA CCI          21.046901
# 1           Chopping et al.          18.783055
# 2                  GEDI L4B         164.080719
# 3                Liu et al.          37.921211
# 4                    LT-GNN          31.403246
# 5          Menlove & Healey         114.922806
# 6                 Xu et al.          69.325028
#
# dataset                                               \
# site_name Smithsonian Conservation Biology Institute
# site_id                                         SCBI
# X                                 -78.13949999999994
# Y                                  38.89292000000006
# 0                                          21.046901
# 1                                          18.783055
# 2                                         334.279755
# 3                                         115.212837
# 4                                          31.403246
# 5                                         106.782768
# 6                                          69.325028
#
# dataset                                                         \
# site_name Ordway-Swisher Biological Station             UNDERC
# site_id                                OSBS               UNDE
# X                        -81.99342999999999 -89.53724999999997
# Y                         29.68927000000008  46.23388000000006
# 0                                 21.046901          21.046901
# 1                                 18.783055          18.783055
# 2                                 63.379155         155.069643
# 3                                 69.890287         139.331772
# 4                                 31.403246          31.403246
# 5                                 42.734001          91.699257
# 6                                 69.325028          69.325028
#
# dataset                                                        \
# site_name Konza Prairie Biological Station          Oak Ridge
# site_id                               KONZ               ORNL
# X                                -96.56309 -84.28259999999995
# Y                        39.10077000000007  35.96412000000004
# 0                                21.046901          21.046901
# 1                                18.783055          18.783055
# 2                                 7.477551         162.482702
# 3                                10.838812          91.845345
# 4                                31.403246          31.403246
# 5                                10.135107         115.705890
# 6                                69.325028          69.325028
#
# dataset                                                 \
# site_name Talladega National Forest          Woodworth
# site_id                        TALL               WOOD
# X                -87.39326999999997 -99.24135599999994
# Y                 32.95046000000008  47.12822800000004
# 0                         21.046901          21.046901
# 1                         18.783055          18.783055
# 2                        228.355491           4.161302
# 3                         85.784576           9.719982
# 4                         31.403246          31.403246
# 5                        125.903267           0.000000
# 6                         69.325028          69.325028
#
# dataset                                      ...  \
# site_name Central Plains Experimental Range  ...
# site_id                                CPER  ...
# X                            -104.745602469  ...
# Y                         40.81553413400008  ...
# 0                                 21.046901  ...
# 1                                  0.000000  ...
# 2                                  1.268689  ...
# 3                                  9.621728  ...
# 4                                 31.403246  ...
# 5                                  0.000000  ...
# 6                                  0.000000  ...
#
# dataset                               Ameriflux                              \
# site_name NEON Talladega National Forest (TALL) NEON Lower Teakettle (TEAK)
# site_id                                  US-xTA                      US-xTE
# X                                      -87.3933                    -119.006
# Y                                       32.9505                     37.0058
# 0                                     21.046901                  141.225123
# 1                                     18.783055                  226.943207
# 2                                    228.293116                  113.171759
# 3                                     85.784576                   40.415094
# 4                                     31.403246                  248.404526
# 5                                    125.903267                  176.307236
# 6                                     69.325028                  176.820676
#
# dataset                          \
# site_name NEON Treehaven (TREE)
# site_id                  US-xTR
# X                      -89.5857
# Y                       45.4937
# 0                     21.046901
# 1                     18.783055
# 2                    111.140861
# 3                     51.776399
# 4                     31.403246
# 5                     44.224957
# 6                     69.325028
#
# dataset                                                       \
# site_name NEON The University of Kansas Field Station (UKFS)
# site_id                                               US-xUK
# X                                                   -95.1921
# Y                                                    39.0404
# 0                                                  21.046901
# 1                                                  18.783055
# 2                                                  88.286984
# 3                                                  27.528269
# 4                                                  31.403246
# 5                                                  29.088547
# 6                                                  69.325028
#
# dataset                                                                       \
# site_name NEON University of Notre Dame Environmental Research Center (UNDE)
# site_id                                                               US-xUN
# X                                                                   -89.5373
# Y                                                                    46.2339
# 0                                                  21.046901
# 1                                                  18.783055
# 2                                                 155.035292
# 3                                                 139.331772
# 4                                                  31.403246
# 5                                                  91.699257
# 6                                                  69.325028
#
# dataset                                                                     \
# site_name NEON Woodworth (WOOD) NEON Wind River Experimental Forest (WREF)
# site_id                  US-xWD                                     US-xWR
# X                      -99.2414                                  -121.9519
# Y                       47.1282                                    45.8205
# 0                     21.046901                                 244.415145
# 1                     18.783055                                  18.783055
# 2                      4.150213                                 357.726868
# 3                      9.719900                                 194.783264
# 4                     31.403246                                  31.403246
# 5                      0.000000                                 320.595123
# 6                     69.325028                                 819.682068
#
# dataset                                                                        \
# site_name NEON Yellowstone Northern Range (Frog Rock) (YELL) Yellow Cab urban
# site_id                                               US-xYE           US-Ylw
# X                                                  -110.5391         -95.3536
# Y                                                    44.9535          29.7894
# 0                                                   7.986143        21.046901
# 1                                                  18.783055        18.783055
# 2                                                  37.207724         7.105864
# 3                                                  59.854660        20.670036
# 4                                                  31.403246        31.403246
# 5                                                  36.563770         8.727328
# 6                                                  79.867683        69.325028
#
# dataset   cluster
# site_name
# site_id
# X
# Y
# 0               1
# 1               1
# 2               0
# 3               3
# 4               4
# 5               0
# 6               2
#
# [7 rows x 499 columns]

# %%
# Save the clustering results to a CSV file
biomass_data_clustered.to_csv('By_Prod\product_clusters_k_US.csv', index=False)

corr_matrix=plot_heat_by_clus(biomass_data_clustered,products)
# Out:
# biomass_data_clustered has more columns than rows, clustering occured on products
# Cluster 1 contains multiple products, plotting heatmap...
# Cluster 0 contains multiple products, plotting heatmap...

# %%
# METRICS

# Extract predicted cluster labels
predicted_labels = biomass_data_clustered['cluster']

print_indices(data_scaled, predicted_labels)
# Out:
# Silhouette Coefficient: 0.14337683231987178
# Calinski-Harabasz Index: 4.049430648681313
# Davies-Bouldin Index: 0.5097690918990825

# %% [markdown]
# ## DBSCAN

# %%
# DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=4)  # Adjust the parameters as needed
clusters_d = dbscan.fit_predict(data_scaled)

# Add cluster labels to the transposed DataFrame, for 1)
data_imputed.loc[:,'cluster'] = clusters

# Transpose the data back to the original format
biomass_data_clustered_d = data_imputed.reset_index()

clusters_d
if -1 in clusters_h:
    print("noise found during clustering, contained in cluster -1")

# %%
biomass_data_clustered_d
# Out:
# dataset               index               NEON  \
# site_name                       Harvard Forest
# site_id                                   HARV
# X                           -72.17265999999995
# Y                            42.53690000000006
# 0                   ESA CCI          21.046901
# 1           Chopping et al.          18.783055
# 2                  GEDI L4B         164.080719
# 3                Liu et al.          37.921211
# 4                    LT-GNN          31.403246
# 5          Menlove & Healey         114.922806
# 6                 Xu et al.          69.325028
#
# dataset                                               \
# site_name Smithsonian Conservation Biology Institute
# site_id                                         SCBI
# X                                 -78.13949999999994
# Y                                  38.89292000000006
# 0                                          21.046901
# 1                                          18.783055
# 2                                         334.279755
# 3                                         115.212837
# 4                                          31.403246
# 5                                         106.782768
# 6                                          69.325028
#
# dataset                                                         \
# site_name Ordway-Swisher Biological Station             UNDERC
# site_id                                OSBS               UNDE
# X                        -81.99342999999999 -89.53724999999997
# Y                         29.68927000000008  46.23388000000006
# 0                                 21.046901          21.046901
# 1                                 18.783055          18.783055
# 2                                 63.379155         155.069643
# 3                                 69.890287         139.331772
# 4                                 31.403246          31.403246
# 5                                 42.734001          91.699257
# 6                                 69.325028          69.325028
#
# dataset                                                        \
# site_name Konza Prairie Biological Station          Oak Ridge
# site_id                               KONZ               ORNL
# X                                -96.56309 -84.28259999999995
# Y                        39.10077000000007  35.96412000000004
# 0                                21.046901          21.046901
# 1                                18.783055          18.783055
# 2                                 7.477551         162.482702
# 3                                10.838812          91.845345
# 4                                31.403246          31.403246
# 5                                10.135107         115.705890
# 6                                69.325028          69.325028
#
# dataset                                                 \
# site_name Talladega National Forest          Woodworth
# site_id                        TALL               WOOD
# X                -87.39326999999997 -99.24135599999994
# Y                 32.95046000000008  47.12822800000004
# 0                         21.046901          21.046901
# 1                         18.783055          18.783055
# 2                        228.355491           4.161302
# 3                         85.784576           9.719982
# 4                         31.403246          31.403246
# 5                        125.903267           0.000000
# 6                         69.325028          69.325028
#
# dataset                                      ...  \
# site_name Central Plains Experimental Range  ...
# site_id                                CPER  ...
# X                            -104.745602469  ...
# Y                         40.81553413400008  ...
# 0                                 21.046901  ...
# 1                                  0.000000  ...
# 2                                  1.268689  ...
# 3                                  9.621728  ...
# 4                                 31.403246  ...
# 5                                  0.000000  ...
# 6                                  0.000000  ...
#
# dataset                               Ameriflux                              \
# site_name NEON Talladega National Forest (TALL) NEON Lower Teakettle (TEAK)
# site_id                                  US-xTA                      US-xTE
# X                                      -87.3933                    -119.006
# Y                                       32.9505                     37.0058
# 0                                     21.046901                  141.225123
# 1                                     18.783055                  226.943207
# 2                                    228.293116                  113.171759
# 3                                     85.784576                   40.415094
# 4                                     31.403246                  248.404526
# 5                                    125.903267                  176.307236
# 6                                     69.325028                  176.820676
#
# dataset                          \
# site_name NEON Treehaven (TREE)
# site_id                  US-xTR
# X                      -89.5857
# Y                       45.4937
# 0                     21.046901
# 1                     18.783055
# 2                    111.140861
# 3                     51.776399
# 4                     31.403246
# 5                     44.224957
# 6                     69.325028
#
# dataset                                                       \
# site_name NEON The University of Kansas Field Station (UKFS)
# site_id                                               US-xUK
# X                                                   -95.1921
# Y                                                    39.0404
# 0                                                  21.046901
# 1                                                  18.783055
# 2                                                  88.286984
# 3                                                  27.528269
# 4                                                  31.403246
# 5                                                  29.088547
# 6                                                  69.325028
#
# dataset                                                                       \
# site_name NEON University of Notre Dame Environmental Research Center (UNDE)
# site_id                                                               US-xUN
# X                                                                   -89.5373
# Y                                                                    46.2339
# 0                                                  21.046901
# 1                                                  18.783055
# 2                                                 155.035292
# 3                                                 139.331772
# 4                                                  31.403246
# 5                                                  91.699257
# 6                                                  69.325028
#
# dataset                                                                     \
# site_name NEON Woodworth (WOOD) NEON Wind River Experimental Forest (WREF)
# site_id                  US-xWD                                     US-xWR
# X                      -99.2414                                  -121.9519
# Y                       47.1282                                    45.8205
# 0                     21.046901                                 244.415145
# 1                     18.783055                                  18.783055
# 2                      4.150213                                 357.726868
# 3                      9.719900                                 194.783264
# 4                     31.403246                                  31.403246
# 5                      0.000000                                 320.595123
# 6                     69.325028                                 819.682068
#
# dataset                                                                        \
# site_name NEON Yellowstone Northern Range (Frog Rock) (YELL) Yellow Cab urban
# site_id                                               US-xYE           US-Ylw
# X                                                  -110.5391         -95.3536
# Y                                                    44.9535          29.7894
# 0                                                   7.986143        21.046901
# 1                                                  18.783055        18.783055
# 2                                                  37.207724         7.105864
# 3                                                  59.854660        20.670036
# 4                                                  31.403246        31.403246
# 5                                                  36.563770         8.727328
# 6                                                  79.867683        69.325028
#
# dataset   cluster
# site_name
# site_id
# X
# Y
# 0               1
# 1               1
# 2               0
# 3               3
# 4               4
# 5               0
# 6               2
#
# [7 rows x 499 columns]

# %%
# Save the clustering results to a CSV file
biomass_data_clustered_d.to_csv('By_Prod\product_clusters_d_US.csv', index=False)

corr_matrix=plot_heat_by_clus(biomass_data_clustered_d,products)
# Out:
# biomass_data_clustered has more columns than rows, clustering occured on products
# Cluster 1 contains multiple products, plotting heatmap...
# Cluster 0 contains multiple products, plotting heatmap...

# %%
# METRICS

# Extract predicted cluster labels
predicted_labels = biomass_data_clustered['cluster']

print_indices(data_scaled, predicted_labels)
# Out:
# Silhouette Coefficient: 0.14337683231987178
# Calinski-Harabasz Index: 4.049430648681313
# Davies-Bouldin Index: 0.5097690918990825
